# %%
import pandas as pd
import numpy as np
import pulp as pl
import geopy.distance as d
from concurrent.futures import ThreadPoolExecutor, as_completed
from collections import defaultdict

# %%
shipment = pd.read_csv('Shipments.csv')
location = pd.read_csv('Locations.csv')
bagging = pd.read_csv('Bagging activities.csv')
loc_trans = pd.read_csv('Location transfers.csv')
begin_inv = pd.read_csv('Beginning inventory.csv')

# %% [markdown]
# ## List of warehouses being considered for the model

# %%
grp_frm_df = loc_trans[loc_trans['FISCALYEAR'] == 2024].groupby(['FROMLOCATION']).agg({'NETUNITS' : 'sum'}).reset_index().rename(columns = {'NETUNITS' : 'total_units_from'})
grp_to_df = loc_trans[loc_trans['FISCALYEAR'] == 2024].groupby(['TOLOCATION']).agg({'NETUNITS' : 'sum'}).reset_index().rename(columns = {'NETUNITS' : 'total_units_to'})

grp_df = grp_frm_df.merge(grp_to_df, how = 'outer', left_on = 'FROMLOCATION', right_on = 'TOLOCATION')

grp_df[(grp_df.total_units_to >= 10000) & (grp_df.total_units_from >= 10000)]
# Out:
#    FROMLOCATION  total_units_from TOLOCATION  total_units_to
# 1             B          265189.0          B        185336.5
# 3             E          297559.0          E        270732.0
# 4           EBF           87424.5        EBF         39320.0
# 5           FDC           12709.0        FDC         44911.0
# 6             I          311550.5          I        148700.5
# 8             M           34252.5          M         56847.5
# 10            S           48400.0          S        329310.5

# %%
# This list was derived from the conditions above
wh_list = ['B', 'E', 'I', 'M', 'S']

# %% [markdown]
# ## Reference Year

# %%
customer_year_of_ref = [2023, 2024]
supply_year_of_ref = 2024

# %% [markdown]
# ### Calculating all the distances for the required customers and WHs

# %%
cust_df = shipment[(shipment['FISCALYEAR'].isin(customer_year_of_ref)) &
                  (shipment['SHIPGPSLATITUDE'] != 0) &
                  (shipment['SHIPGPSLONGITUDE'] != 0)&
                  (shipment['NETUNITS'] <= 0)][['KEYCUSTOMER', 'SHIPGPSLATITUDE', 'SHIPGPSLONGITUDE']].drop_duplicates()

cust_df['latlong'] = cust_df['SHIPGPSLATITUDE'].astype(str) + '-' + cust_df['SHIPGPSLONGITUDE'].astype(str)
cust_df['row_number'] = cust_df.groupby('KEYCUSTOMER')['latlong'].rank('first')
cust_df = cust_df[cust_df['row_number'] == 1]

cust_df.rename(columns = {'KEYCUSTOMER' : 'LOCATION'}, inplace = True)
cust_df['TYPE'] = 'Customer'


wh_df = location[location['LOCATION'].isin(wh_list)][['LOCATION', 'SHIPGPSLATITUDE', 'SHIPGPSLONGITUDE']].drop_duplicates()
wh_df['TYPE'] = 'WH'

cust_wh_df = pd.concat([cust_df, wh_df])
wh_df.rename(columns = {'LOCATION' : 'WH_NAME', 'SHIPGPSLATITUDE' : 'WH_SHIPGPSLATITUDE', 'SHIPGPSLONGITUDE' : 'WH_SHIPGPSLONGITUDE'}, inplace = True)
wh_df = wh_df[['WH_NAME', 'WH_SHIPGPSLATITUDE', 'WH_SHIPGPSLONGITUDE']]
cust_wh_df = wh_df.merge(cust_wh_df, how = 'cross')

cust_wh_df['distance_miles'] = cust_wh_df.apply(
        lambda row: d.geodesic((row['WH_SHIPGPSLATITUDE'], row['WH_SHIPGPSLONGITUDE']), (row['SHIPGPSLATITUDE'], row['SHIPGPSLONGITUDE'])).miles, axis=1
    )

# %%
dist_df = cust_wh_df[['WH_NAME', 'LOCATION', 'distance_miles']]
dist_df['distance_miles'] = round(dist_df['distance_miles'], 2)
dist_df = dist_df[(dist_df['distance_miles'] != 0)]
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2456627460.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dist_df['distance_miles'] = round(dist_df['distance_miles'], 2)

# %% [markdown]
# ### Segment Customers

# %%
cust_units_df = shipment[(shipment['FISCALYEAR'].isin(customer_year_of_ref)) &
                  (shipment['SHIPGPSLATITUDE'] != 0) &
                  (shipment['SHIPGPSLONGITUDE'] != 0) &
                  (shipment['NETUNITS'] <= 0)][['KEYCUSTOMER', 'NETUNITS']]

cust_units_df = cust_units_df.groupby(['KEYCUSTOMER']).agg({'NETUNITS' : 'sum'}).reset_index()

cust_units_df['NETUNITS'] = 0 - cust_units_df['NETUNITS']

# %% [markdown]
# ## Modify the thresholds below to change the cluster definition

# %%
cust_units_df['cluster'] = np.where(cust_units_df['NETUNITS'] < 800, 'C0',
                                    np.where((cust_units_df['NETUNITS'] >= 800) & (cust_units_df['NETUNITS'] < 2100), 'C2',
                                             np.where(cust_units_df['NETUNITS'] >= 2100, 'C1', 'NA')))

# %% [markdown]
# ## Defining the variables required for dictionaries for the model

# %%
supply_constraint_multiplier = 1.15
high_demand_constraint_mulitplier = 1.1
regular_demand_constraint_mulitplier = 1
low_demand_constraint_mulitplier = 0.9

# defining the dictionary with the required states and their probabilities
scenarios_arg = {'C0-Low Demand, C2-Low Demand, C1-Low Demand' : 0.1,
 'C0-Low Demand, C2-Low Demand, C1-Regular Demand': 0.1,
 'C0-Low Demand, C2-Low Demand, C1-High Demand': 0.1,
 'C0-Low Demand, C2-Regular Demand, C1-Regular Demand': 0.1,
 'C0-Low Demand, C2-Regular Demand, C1-High Demand': 0.1,
 'C0-Low Demand, C2-High Demand, C1-High Demand': 0.1,
 'C0-Regular Demand, C2-Regular Demand, C1-Regular Demand': 0.1,
 'C0-Regular Demand, C2-Regular Demand, C1-High Demand': 0.1,
 'C0-Regular Demand, C2-High Demand, C1-High Demand': 0.1,
 'C0-High Demand, C2-High Demand, C1-High Demand' : 0.1}

warehouses_arg = list(dist_df.WH_NAME.unique())
customers_arg = list(cust_units_df.KEYCUSTOMER.unique())

scenario_list_arg = list(scenarios_arg.keys())

# %% [markdown]
# ### Converting distance dataframe to a dictionary for the model

# %%
# %%time

wh_dist_df = dist_df[dist_df.LOCATION.isin(warehouses_arg)]
cust_dist_df = dist_df[~(dist_df.LOCATION.isin(warehouses_arg))]

warehouse_to_customer_distances_arg = {}
warehouse_to_warehouse_distances_arg = {}

for w in warehouses_arg:
  for c in customers_arg:
    # print(c)
    c_dist = cust_dist_df[(cust_dist_df['LOCATION'] == c) & (cust_dist_df['WH_NAME'] == w)]
    warehouse_to_customer_distances_arg[(w, c)] = c_dist['distance_miles'].item()

for w1 in warehouses_arg:
  for w2 in warehouses_arg:
    if w1 != w2:
      w_dist = wh_dist_df[(wh_dist_df['WH_NAME'] == w1) & (wh_dist_df['LOCATION'] == w2)]
      warehouse_to_warehouse_distances_arg[(w1, w2)] = w_dist['distance_miles'].item()
# Out:
# CPU times: total: 1min 35s
# Wall time: 3min 9s

# %% [markdown]
# ### Creating warehouse capacity dictionary for the model

# %%
# 2. WH Capacity

bag_df = bagging[(bagging['FISCALYEAR'] == supply_year_of_ref) &
                 (bagging['LOCATION'].isin(wh_list)) &
                 (bagging['NETUNITS'] >= 0)
                 ].groupby(['LOCATION', 'PRODSUB0']).agg({'NETUNITS' : 'sum'}).reset_index().rename(columns = {'NETUNITS' : 'NETUNITS_prodn'})

bag_df['NETUNITS_prodn'] = bag_df['NETUNITS_prodn']* supply_constraint_multiplier

begin_inv_df = begin_inv[(begin_inv['FISCALYEAR'] == supply_year_of_ref) &
                 (begin_inv['LOCATION'].isin(wh_list)) &
                 (begin_inv['NETUNITS'] >= 0)
                 ].groupby(['LOCATION', 'PRODSUB0']).agg({'NETUNITS' : 'sum'}).reset_index().rename(columns = {'NETUNITS' : 'NETUNITS_beginbal'})


bag_df = bag_df.merge(begin_inv_df, on = ['LOCATION', 'PRODSUB0'], how = 'outer')
bag_df['NETUNITS_beginbal'] = bag_df['NETUNITS_beginbal'].fillna(0)
bag_df['NETUNITS_prodn'] = bag_df['NETUNITS_prodn'].fillna(0)

bag_df['NETUNITS'] = bag_df['NETUNITS_beginbal'] + bag_df['NETUNITS_prodn']

to_loc_df = loc_trans[(loc_trans['FISCALYEAR'] == supply_year_of_ref) &
                 (loc_trans['TOLOCATION'].isin(wh_list))
                 ].groupby(['TOLOCATION', 'PRODSUB0']).agg({'NETUNITS' : 'sum'}).reset_index().rename(columns = {'TOLOCATION' : 'LOCATION'})

from_loc_df = loc_trans[(loc_trans['FISCALYEAR'] == supply_year_of_ref) &
                 (loc_trans['FROMLOCATION'].isin(wh_list))
                 ].groupby(['FROMLOCATION', 'PRODSUB0']).agg({'NETUNITS' : 'sum'}).reset_index().rename(columns = {'FROMLOCATION' : 'LOCATION'})


cap_df = pd.concat([bag_df,to_loc_df,from_loc_df])

cap_df = cap_df.groupby(['LOCATION', 'PRODSUB0']).agg({'NETUNITS' : 'max'}).reset_index()

# %% [markdown]
# ### Creating customer-scenario-demand dictionary for the model

# %%
# %%time

# 3. Customer demand for each scenario - let us assume they are all equal for the time being

scenario_intm_df = cust_units_df[['KEYCUSTOMER', 'cluster']].drop_duplicates()

units_intm_df = shipment[(shipment['FISCALYEAR'] == supply_year_of_ref) &
                  (shipment['SHIPGPSLATITUDE'] != 0) &
                  (shipment['SHIPGPSLONGITUDE'] != 0) &
                  (shipment['NETUNITS'] <= 0)].groupby(['KEYCUSTOMER', 'PRODSUB0']).agg({'NETUNITS' : 'sum'}).reset_index()

units_intm_df['NETUNITS'] = round(0 - units_intm_df['NETUNITS'],2)

scenario_intm_df = scenario_intm_df.merge(units_intm_df, on = ['KEYCUSTOMER'], how = 'inner')

demand_values_df = pd.DataFrame(['High Demand', 'Regular Demand', 'Low Demand'], columns = ['demand'])

scenario_df = scenario_intm_df.merge(demand_values_df, how = 'cross')

scenario_df['NETUNITS'] = np.where(scenario_df['demand'] == 'High Demand', scenario_df['NETUNITS']*high_demand_constraint_mulitplier,
                                np.where(scenario_df['demand'] == 'Low Demand', scenario_df['NETUNITS']*low_demand_constraint_mulitplier, scenario_df['NETUNITS']*regular_demand_constraint_mulitplier))
# Out:
# CPU times: total: 62.5 ms
# Wall time: 129 ms

# %%
def scenario_df_creator(df, scenario_list):
    df_list = []
    for ky in scenario_list:
        cluster_scenarios = ky.split(',')
        for cs in cluster_scenarios:
            case_df = df[(df['demand'] == cs.split('-')[1].strip()) & (df['cluster'] == cs.split('-')[0].strip())]
            case_df['scenario'] = ky
            df_list.append(case_df)
            
    return df_list

# %%
final_scenarios_df_list = scenario_df_creator(scenario_df, scenario_list_arg)
final_scenarios_df = pd.concat(final_scenarios_df_list)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28740\2578629555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   case_df['scenario'] = ky

# %% [markdown]
# # The model

# %% [markdown]
# ## Defining the variables required for the model

# %%
stage1_transfers_penalty = 1.75
truck_capacity_arg = 675

prodsub0_list = list(shipment[(shipment['FISCALYEAR'] == supply_year_of_ref) &
                  (shipment['SHIPGPSLATITUDE'] != 0) &
                  (shipment['SHIPGPSLONGITUDE'] != 0) &
                  (shipment['NETUNITS'] <= 0)].sort_values('NETUNITS', ascending = True)['PRODSUB0'].unique())

# %%
# %%time
# Initialize the dictionary with defaultdict to handle nested structure
customer_demands_arg = defaultdict(dict)

# Populate with existing data
for _, row in final_scenarios_df.iterrows():
    product = row["PRODSUB0"]
    scenario_customer = (row["scenario"], row["KEYCUSTOMER"])
    customer_demands_arg[product][scenario_customer] = row["NETUNITS"]

# Ensure all products, scenarios, and customers have at least a 0 value
all_products = set(shipment[(shipment['FISCALYEAR'] == 2024) &
                  (shipment['SHIPGPSLATITUDE'] != 0) &
                  (shipment['SHIPGPSLONGITUDE'] != 0) &
                  (shipment['NETUNITS'] <= 0)].sort_values('NETUNITS', ascending = True)['PRODSUB0'].unique())

all_scenarios = set(scenarios_arg.keys())
all_customers = set(cust_units_df.KEYCUSTOMER.unique())

for product in all_products:
    for scenario in all_scenarios:
        for customer in all_customers:
            if (scenario, customer) not in customer_demands_arg[product]:
                customer_demands_arg[product][(scenario, customer)] = 0

# Convert defaultdict to a normal dictionary
customer_demands_arg = dict(customer_demands_arg)

# Initialize the dictionary for warehouse capacities
warehouse_capacities_arg = defaultdict(dict)

# Populate with existing data
for _, row in cap_df.iterrows():
    product = row["PRODSUB0"]
    warehouse = row["LOCATION"]
    warehouse_capacities_arg[product][warehouse] = row["NETUNITS"]

# Ensure all products and warehouses have at least a 0 value
all_warehouses = set(dist_df.WH_NAME.unique())

for product in all_products:
    for warehouse in all_warehouses:
        if warehouse not in warehouse_capacities_arg[product]:
            warehouse_capacities_arg[product][warehouse] = 0

# Convert defaultdict to a normal dictionary
warehouse_capacities_arg = dict(warehouse_capacities_arg)
# Out:
# CPU times: total: 27.2 s
# Wall time: 35 s

# %%
# Define a function to solve the model for a single product
def solve_optimization(product_id, warehouses, customers, scenarios, warehouse_capacities, warehouse_to_customer_distances, warehouse_to_warehouse_distances, customer_demands, truck_capacity, stage1_transfers_penalty):
    # Retrieve product-specific warehouse capacities and customer demands
    product_warehouse_capacities = warehouse_capacities[product_id]
    product_customer_demands = customer_demands[product_id]
    
    print("Running the model for product " + product_id)
    # === Create Model ===
    model = pl.LpProblem("Ag_Two_Stage_Stochastic_LP", pl.LpMinimize)
    
    # === First Stage Variables: warehouse to customer shipments ===
    x = pl.LpVariable.dicts(
        "x",
        [(w, c, s) for w in warehouses for c in customers for s in scenarios],
        lowBound=0,
        cat='Integer'
    )
    
    # === Second Stage Variables: warehouse to warehouse shipments for each scenario ===
    y = pl.LpVariable.dicts(
        "y",
        [(w1, w2, s) for w1 in warehouses for w2 in warehouses if w1 != w2 for s in scenarios],
        lowBound=0,
        cat='Integer'
    )
    
    # === Objective Function ===
    # Stage 1 cost
    stage1_cost = pl.lpSum(
    scenarios[s] * (x[w, c, s]) * warehouse_to_customer_distances[w, c]
    for w in warehouses for c in customers for s in scenarios
    )
    
    # Stage 2 cost (weighted over scenarios)
    stage2_cost = pl.lpSum(
        scenarios[s] * (y[w1, w2, s]) * warehouse_to_warehouse_distances[w1, w2]
        for w1 in warehouses for w2 in warehouses if w1 != w2 for s in scenarios
    )
    
    # Set total objective
    model += stage1_transfers_penalty*stage1_transfers_penalty*(stage1_cost/truck_capacity) + (stage2_cost/truck_capacity), "Total_Distance_Cost"
    
    # === Constraints ===
    
    # 1. Supply Constraint for each warehouse
    for w in warehouses:
        for s in scenarios:
            # Total outflow (to customers and other warehouses)
            outflow_customers = pl.lpSum(x[w, c, s] for c in customers)
            outflow_warehouses = pl.lpSum(y[w, w2, s] for w2 in warehouses if w2 != w)
            total_outflow = outflow_customers + outflow_warehouses
    
            # Total inflow (from other warehouses)
            inflow_warehouses = pl.lpSum(y[w1, w, s] for w1 in warehouses if w1 != w)
    
            # Supply constraint: outflow ≤ inflow + warehouse capacity
            model += (total_outflow <= inflow_warehouses + product_warehouse_capacities[w]), f"SupplyConstraint_{w}_Scenario_{s}"
    
    # 2. Demand Constraint for each customer and scenario
    for c in customers:
        for s in scenarios:
            total_supply = pl.lpSum(x[w, c, s] for w in warehouses)
            model += (total_supply >= product_customer_demands[s, c]), f"DemandConstraint_{c}_Scenario_{s}"
    
    # === Solve the Model ===
    solver = pl.PULP_CBC_CMD(msg=True)  # Use CBC Solver
    model.solve(solver)
    # print('model done')

    # === Extract Results ===
    results = []

    # Stage 1 Variables: Warehouse to Customer Shipments
    for (w, c, s), var in x.items():
        if var.varValue > 0:  # Only store nonzero values
            results.append(["Warehouse_to_Customer", w, c, s, var.varValue])
    
    # Stage 2 Variables: Warehouse to Warehouse Shipments (Scenario-based)
    for (w1, w2, s), var in y.items():
        if var.varValue > 0:  # Only store nonzero values
            results.append(["Warehouse_to_Warehouse", w1, w2, s, var.varValue])
    
    # Convert results to DataFrame
    results_df = pd.DataFrame(results, columns=["Variable_Type", "Warehouse_1", "Warehouse_2/Customer", "Scenario", "Optimal_Value"])
    
    # Add Objective Function Value and Status
    summary_data = pd.DataFrame([
        ["Objective_Value", "-", "-", "-", pl.value(model.objective)],
        ["Status", "-", "-", "-", pl.LpStatus[model.status]]
    ], columns=["Variable_Type", "Warehouse_1", "Warehouse_2/Customer", "Scenario", "Optimal_Value"])
    
    # Combine results and summary data
    final_results_df = pd.concat([results_df, summary_data], ignore_index=True)
    final_results_df['ProdSub0'] = product_id

    # print('results returned')

    return final_results_df

# %%
# Function to handle concurrent execution

def run_parallel_optimization(products, warehouses, customers, scenarios, warehouse_capacities, warehouse_to_customer_distances, warehouse_to_warehouse_distances, customer_demands, truck_capacity, stage1_transfers_penalty, final_df, num_threads=10):
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        futures = [executor.submit(solve_optimization, prod, warehouses, customers, scenarios, warehouse_capacities, warehouse_to_customer_distances, warehouse_to_warehouse_distances, customer_demands, truck_capacity, stage1_transfers_penalty) for prod in products]
        
        for future in as_completed(futures):
            df_results = future.result()
            if len(df_results) > 0:
                final_df = pd.concat([final_df, df_results])
                
    return final_df

# %%
# %%time

output_empty_df = pd.DataFrame(columns=["Variable_Type", "Warehouse_1", "Warehouse_2/Customer", "Scenario", "Optimal_Value", "ProdSub0"])

# Run the function
output_df = run_parallel_optimization(prodsub0_list, warehouses_arg, customers_arg, scenarios_arg, warehouse_capacities_arg, warehouse_to_customer_distances_arg, warehouse_to_warehouse_distances_arg, customer_demands_arg, truck_capacity_arg, stage1_transfers_penalty, output_empty_df)
# Out:
# Running the model for product 5618STXRIB
# Running the model for product 47C77VT2RIB
# Running the model for product 639-03VT2RIB
# Running the model for product 5701VT2PRO
# Running the model for product 34C14
# Running the model for product 6659RR
# Running the model for product 6659VT2PRO
# Running the model for product ES7514VT2P
# Running the model for product 645-16VT2PRO
# Running the model for product 645-16VT2RIB
# Running the model for product 636-16VT2RIB
# Running the model for product 5494VT2RIB
# Running the model for product 44C27VT2RIB
# Running the model for product 66C28-3110
# Running the model for product 643-52VT2RIB
# Running the model for product 2475VT2RIB
# Running the model for product 643-52VT2PRO
# Running the model for product 6499STXRIB
# Running the model for product 647-79VT2PRO
# Running the model for product 60C12-3330AEZ
# Running the model for product 640-12STXRIB
# Running the model for product ES7698-3110
# Running the model for product ES7514
# Running the model for product 51C62VT2RIB
# Running the model for product 630-04VT2RIB
# Running the model for product 645-80-3110
# Running the model for product 67C91STX
# Running the model for product 66C44VT2RIB
# Running the model for product 58C77-5222EZ
# Running the model for product 6572VT2RIB
# Running the model for product 646-30VT2RIB
# Running the model for product 42C16VT2RIB
# Running the model for product ES7531-3110
# Running the model for product 32C25VT2RIB
# Running the model for product 66C06VT2RIB
# Running the model for product 6572
# Running the model for product 44C27STXRIB
# Running the model for product 59C72VT2RIB
# Running the model for product 37C33VT2RIB
# Running the model for product 68C59-5222
# Running the model for product 642-59VT2PRO
# Running the model for product 639-40VT2RIB
# Running the model for product 5525VT2RIB
# Running the model for product 625-78VT2RIB
# Running the model for product 642-05VT2RIBD1
# Running the model for product 643-52STXRIB
# Running the model for product 67C07VT2PRO
# Running the model for product 64C20-3220EZ
# Running the model for product 644-19-3220EZ
# Running the model for product 65C14TRC
# Running the model for product 645-16
# Running the model for product 5465VT2RIB
# Running the model for product 68C88VT2PRO
# Running the model for product 63C77STXRIB
# Running the model for product 35C79VT2RIB
# Running the model for product 60C12-5222AEZ
# Running the model for product 640-51WX
# Running the model for product 643-17W
# Running the model for product 66C44STXRIB
# Running the model for product 5701RR
# Running the model for product 64C20-5222EZ
# Running the model for product 64C20
# Running the model for product 647-90VT2RIB
# Running the model for product 643-01WX
# Running the model for product 636-39-3110
# Running the model for product 644-04
# Running the model for product 6499STX
# Running the model for product 38C47VT2RIB
# Running the model for product 636-11VT2RIB
# Running the model for product 644-64VT2RIB
# Running the model for product 641-54VT2RIB
# Running the model for product 644-19
# Running the model for product 66C06VT2PRO
# Running the model for product 49C28VT2RIB
# Running the model for product 46C73VT2RIB
# Running the model for product 64C43VT2RIB
# Running the model for product 5717VT2PRO
# Running the model for product 36C62VT2RIB
# Running the model for product 636-16-5222EZ
# Running the model for product 64C30TRC
# Running the model for product 5650VT2RIB
# Running the model for product 42C24
# Running the model for product 54C76STXRIB
# Running the model for product 66C32STX
# Running the model for product 63C82DGVT2RIB
# Running the model for product 62C07-3110
# Running the model for product 67C07VT2RIB
# Running the model for product 642-76VT2RIB
# Running the model for product 62C22VT2RIB
# Running the model for product 645-16STXRIB
# Running the model for product 632-68VT2RIB
# Running the model for product 629-55VT2RIB
# Running the model for product 642-99WX
# Running the model for product 45C21-5122EZ
# Running the model for product 65C76
# Running the model for product 5525
# Running the model for product 60C33VT2RIB
# Running the model for product 66C44
# Running the model for product 6544VT2RIB
# Running the model for product 29C19VT2RIB
# Running the model for product 5643VT2RIB
# Running the model for product 637-55-5222EZ
# Running the model for product 33C30VT2RIB
# Running the model for product 58C48VT2RIB
# Running the model for product 641-85STXRIB
# Running the model for product 62C35VT2RIB
# Running the model for product 5701VT2RIB
# Running the model for product 6619VT2RIBD1
# Running the model for product 42C37-5222AEZ
# Running the model for product 639-70STXRIB
# Running the model for product 6544VT2PRO
# Running the model for product 66C32STXRIB
# Running the model for product 67C91VT2PRO
# Running the model for product 63C54PCE
# Running the model for product 6499
# Running the model for product 36C88
# Running the model for product 66C32VT2PRO
# Running the model for product 648-11VT2PRO
# Running the model for product 640-65-5222AEZ
# Running the model for product 62C52TRCRIB
# Running the model for product 633-14VT2RIB
# Running the model for product 61C34STXRIB
# Running the model for product 42C80VT2RIB
# Running the model for product 628-16VT2RIB
# Running the model for product 63C16W
# Running the model for product 59C72-5222EZ
# Running the model for product 48C87VT2RIB
# Running the model for product 62C71
# Running the model for product 643-37-3110
# Running the model for product 62C35STXRIB
# Running the model for product 5505
# Running the model for product 630-10STXRIB
# Running the model for product 639-91SSPRIB
# Running the model for product 68C18VT2PRO
# Running the model for product 641-78STXRIB
# Running the model for product 628-34
# Running the model for product 66C28-3220EZ
# Running the model for product 66C28
# Running the model for product 641-54STXRIB
# Running the model for product 6499VT2RIB
# Running the model for product 647-46VT2PRO
# Running the model for product 642-59VT2RIB
# Running the model for product 638-19-3110
# Running the model for product 66C28GT
# Running the model for product 5528VT2RIB
# Running the model for product 49C28
# Running the model for product 636-11STXRIB
# Running the model for product 30C98VT2RIB
# Running the model for product 638-74VT2RIB
# Running the model for product 6659VT2RIB
# Running the model for product 67C27STXRIB
# Running the model for product 646-12STX
# Running the model for product 617-78VT2RIB
# Running the model for product 45C94VT2RIB
# Running the model for product 644-19-5222EZ
# Running the model for product 6579STXRIB
# Running the model for product 66C44VT2PRO
# Running the model for product 641-85TRCRIB
# Running the model for product 54C76VT2RIB
# Running the model for product 52C42VT2RIB
# Running the model for product 616-30VT2RIB
# Running the model for product 646-12VT2PRO
# Running the model for product 53C44VT2RIB
# Running the model for product 630-04
# Running the model for product 633-14STXRIB
# Running the model for product 5618
# Running the model for product 619-06VT2RIB
# Running the model for product 632-68
# Running the model for product 644-15WX
# Running the model for product 646-30VT2PRO
# Running the model for product 642-47STXRIB
# Running the model for product 68C18VT2RIB
# Running the model for product 5650
# Running the model for product 630-95-5222EZ
# Running the model for product 5701
# Running the model for product 52C42
# Running the model for product 631-90RR
# Running the model for product 38C48RR
# Running the model for product 61C48VT2RIB
# Running the model for product 648-11VT2RIB
# Running the model for product 52C42RR
# Running the model for product 5427VT2RIB
# Running the model for product 646-30
# Running the model for product 63C66WX
# Running the model for product 49C11STXRIB
# Running the model for product 60C86-5222EZ
# Running the model for product 68C22VT2PRO
# Running the model for product 645-22TRCRIB
# Running the model for product 53C44
# Running the model for product 632-35-5222EZ
# Running the model for product 47C77STXRIB
# Running the model for product 643-24PCE
# Running the model for product 647-35-5222
# Running the model for product 51C48VT2RIB
# Running the model for product 64C36WX
# Running the model for product 58C73
# Running the model for product 650-21VT2RIB
# Running the model for product 5427
# Running the model for product 645-80
# Running the model for product 650-21VT2PRO
# Running the model for product 64C90STXRIB
# Running the model for product 2475RR
# Running the model for product 51C62
# Running the model for product 64C30TRCRIB
# Running the model for product 5643VT2PRO
# Running the model for product 647-42TRC
# Running the model for product 6572VT2PRO
# Running the model for product 625-78STXRIB
# Running the model for product 50C93-5222EZ
# Running the model for product 638-84
# Running the model for product 647-42TRCRIB
# Running the model for product 60C47STXRIB
# Running the model for product 57C33STXRIB
# Running the model for product 56C25SSPRIB
# Running the model for product 644-19-3220
# Running the model for product 644-04-3110
# Running the model for product 627-45VT2RIB
# Running the model for product 63C04
# Running the model for product 636-39
# Running the model for product 65C14TRCRIB
# Running the model for product 5505VT2RIB
# Running the model for product 69C03VT2RIB
# Running the model for product 48C32SSPRIB
# Running the model for product 2602VT2RIB
# Running the model for product 622-65
# Running the model for product 46C24-5222EZ
# Running the model for product 638-44STXRIB
# Running the model for product 6652VT2RIB
# Running the model for product 5700VT2RIB
# Running the model for product 46C57
# Running the model for product 48C87
# Running the model for product 54C55
# Running the model for product 68C59-5222EZ
# Running the model for product 37C33
# Running the model for product 69C03VT2PRO
# Running the model for product 42C37-3220AEZ
# Running the model for product 631-90
# Running the model for product 645-22TRC
# Running the model for product 55C32SSPRIB
# Running the model for product 635-54
# Running the model for product 628-51SSPRIB
# Running the model for product 637-21WX
# Running the model for product 61C48VT2PRO
# Running the model for product 57C33VT2RIB
# Running the model for product 615-01VT2RIB
# Running the model for product 638-19
# Running the model for product 626-20-5122EZ
# Running the model for product 629-12VT2RIB
# Running the model for product 35C41VT2RIB
# Running the model for product 42C24RR
# Running the model for product 646-12STXRIB
# Running the model for product 59C46
# Running the model for product 5650VT2PRO
# Running the model for product 58C73-3110
# Running the model for product 648-11
# Running the model for product 68C88VT2Pro
# Running the model for product 635-81SSPRIB
# Running the model for product 629-22VT2RIB
# Running the model for product 622-65RR
# Running the model for product 56C78
# Running the model for product 6517VT2RIB
# Running the model for product 5499
# Running the model for product 60C86
# Running the model for product 621-89-5222AEZ
# Running the model for product 645-80GT
# Running the model for product 646-17STXRIB
# Running the model for product 643-41
# Running the model for product 636-16
# Running the model for product 636-43VT2RIB
# Running the model for product 5618VT2RIB
# Running the model for product 59C72
# Running the model for product 621-89-3220AEZ
# Running the model for product 36C55
# Running the model for product 49C19
# Running the model for product 54C11-5222EZ
# Running the model for product 42C24VT2RIB
# Running the model for product 5700STXRIB
# Running the model for product 64C90STX
# Running the model for product 615-35
# Running the model for product 59C72STXRIB
# Running the model for product 5505STXRIB
# Running the model for product 6572STXRIB
# Running the model for product 614-21VT2RIB
# Running the model for product 637-55
# Running the model for product 644-32TRC
# Running the model for product 62C35VT2PRO
# Running the model for product 646-12VT2RIB
# Running the model for product 36C55RR
# Running the model for product 67C01VT2PRO
# Running the model for product 59C66VT2RIB
# Running the model for product 642-47STX
# Running the model for product 5590VT2RIB
# Running the model for product 68C18
# Running the model for product 620-82VT2RIB
# Running the model for product 63C82DGVT2PRO
# Running the model for product 621-77VT2RIB
# Running the model for product 635-54VT2RIB
# Running the model for product 6659
# Running the model for product 6267
# Running the model for product A644-04
# Running the model for product 59C46VT2RIB
# Running the model for product 42C63VT2RIB
# Running the model for product 6267VT2RIB
# Running the model for product 59C46RR
# Running the model for product 48C46
# Running the model for product 66C28-3220
# Running the model for product 6652STXRIB
# Running the model for product 55C95VT2RIB
# Running the model for product 636-16STXRIB
# Running the model for product 638-84RR
# Running the model for product 641-06VT2RIB
# Running the model for product 5501VT2RIB
# Running the model for product 625-32VT2RIB
# Running the model for product A644-04-3110
# Running the model for product 5499VT2RIB
# Running the model for product 629-22STXRIB
# Running the model for product 49C62TRCRIB
# Running the model for product A646-12STX
# Running the model for product 58C77
# Running the model for product 62C02VT2RIB
# Running the model for product 6458WX
# Running the model for product 626-08VT2RIB
# Running the model for product 627-83VT2RIB
# Running the model for product 5650STXRIB
# Running the model for product 6544STXRIB
# Running the model for product 5470VT2RIB
# Running the model for product 5565
# Running the model for product 638-84VT2RIB
# Running the model for product 629-22
# Running the model for product 5606STXRIB
# Running the model for product 647-90VT2PRO
# Running the model for product 60C17WX
# Running the model for product 644-32TRCRIB
# Running the model for product 626-08STXRIB
# Running the model for product 61C10
# Running the model for product 5643STXRIB
# Running the model for product 6499VT2PRO
# Running the model for product 629-93
# Running the model for product 638-44VT2RIBD1
# Running the model for product 647-35
# Running the model for product A6659VT2PRO
# Running the model for product 5410VT2RIB
# Running the model for product 642-59STXRIB
# Running the model for product 645-16STX
# Running the model for product 68C22VT2RIB
# Running the model for product 57C97VT2RIB
# Running the model for product 66C44STX
# Running the model for product 53C88
# Running the model for product 615-35RR
# Running the model for product 639-70STX
# Running the model for product 62C18WX
# CPU times: total: 37min 59s
# Wall time: 1h 33min 23s

# %%
output_df.head()
# Out:
#            Variable_Type Warehouse_1 Warehouse_2/Customer  \
# 0  Warehouse_to_Customer           B               246981
# 1  Warehouse_to_Customer           B               246981
# 2  Warehouse_to_Customer           B               246981
# 3  Warehouse_to_Customer           B               246981
# 4  Warehouse_to_Customer           B               246981
#
#                                             Scenario Optimal_Value    ProdSub0
# 0        C0-Low Demand, C2-Low Demand, C1-Low Demand         288.0  5701VT2PRO
# 1    C0-Low Demand, C2-Low Demand, C1-Regular Demand         319.0  5701VT2PRO
# 2       C0-Low Demand, C2-Low Demand, C1-High Demand         351.0  5701VT2PRO
# 3  C0-Low Demand, C2-Regular Demand, C1-Regular D...         319.0  5701VT2PRO
# 4   C0-Low Demand, C2-Regular Demand, C1-High Demand         351.0  5701VT2PRO

# %%
output_df.to_csv("optimization_results.csv", index=False)
